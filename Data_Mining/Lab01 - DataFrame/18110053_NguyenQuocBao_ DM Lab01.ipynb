# %% [markdown]
# ## Data Mining
# ## Lab 1: DataFrame
# ## 18110053 - Nguyễn Quốc Bảo

# %%
import pandas as pd
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image
import warnings
warnings.filterwarnings("ignore")

# %%
print("All Files in the Current Folder :")
os.listdir()
# Out:
# All Files in the Current Folder :
# ['.ipynb_checkpoints',
#  '18110053_NguyenQuocBao_ DM Lab01.ipynb',
#  'CustomerChurn.csv',
#  'Lab01 - DataFrame Tutorials.html',
#  'Telco Customer Churn.csv']

# %% [markdown]
# ## Data description
# * customerID - a unique ID for each customer
# * gender - Whether the customer is male or female
# * SeniorCitizen - Whether the cutsomer is senior citizen or not
# * Partner - Whether the customer has a partner or not
# * Dependents - Whether the customer has dependents or not
# * tenure - Number of months the customer has stayed with the company
# * PhoneService - Whether the customer has a phone service or not
# * MultipleLines - Whether the customer has multiple lines or not
# * InternetService - Customer’s internet service provider
# * OnlineSecurity - Whether the customer has online security or not
# * OnlineBackup - Whether the customer has online backup or not
# * DeviceProtection - Whether the customer has device protection or not
# * TechSupport - Whether the customer has tech support or not
# * StreamingTV - Whether the customer has streaming TV or not
# * StreamingMovies - Whether the customer has streaming movies or not
# * Contract - The contract term of the customer (Month-to-month, One year, Two year)
# * PaperlessBiling - Whether the customer has paperless billing or not
# * PaymentMethod - The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic)
# * MonthlyCharges - The amount charged to the customer monthly
# * TotalCharges - The total amount charged to the customer
# * Churn - Whether the customer churned or not

# %%
# set the max columns to none
pd.set_option('display.max_columns', None)

# Read data and look statistics
import pandas as pd
data = pd.read_csv('Telco Customer Churn.csv')
print("The shape of data in (nrows,ncols)")
print(data.shape)
print("Display all first of 5 rows :")
display(data.head())
# Out:
# The shape of data in (nrows,ncols)
# (7043, 21)
# Display all first of 5 rows :
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
print("How we can see the type of all columns in data ?")
display(data.info())
print("\n")
# Out:
# How we can see the type of all columns in data ?
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
# None

# %%
print("How to extract Index of Dataframe ? \n\t", data.index)
print("\nHow to extract Column of Dataframe in the list type ? \n\t", list(data.columns))
print("\nHow many PaymentMethod are there in the data ? \n\t", data["PaymentMethod"].unique())
print(f"\nWhat is min max value of tenure in the data ? \n\t  \
      from min : {np.min(data['tenure'])} to max : {np.max(data['tenure'])}")
print(f"\nWhat is mean std value of tenure in the data ? \n\t  \
      mean : {data['tenure'].mean()} std : {data['tenure'].std()}")
print(f"\nWhat is sum and median value of tenure in the data ? \n\t  \
      sum : {data['tenure'].sum()} median : {data['tenure'].median()}")
# Out:
# How to extract Index of Dataframe ?
# 	 RangeIndex(start=0, stop=7043, step=1)
#
# How to extract Column of Dataframe in the list type ?
# 	 ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
#
# How many PaymentMethod are there in the data ?
# 	 ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
# What is min max value of tenure in the data ?
# 	        from min : 0 to max : 72
#
# What is mean std value of tenure in the data ?
# 	        mean : 32.37114865824223 std : 24.55948102309423
#
# What is sum and median value of tenure in the data ?
# 	        sum : 227990 median : 29.0

# %%
print("How many cases of gender ?")
print(data["gender"].value_counts())
print("\n")

print("Can we see the statistics table of the whole data ?")
display(data.describe())
print("\n")

print("Is there any missing value at all columns ?")
display(data.isnull().sum())
print("\n")
# Out:
# How many cases of gender ?
# Male      3555
# Female    3488
# Name: gender, dtype: int64
#
#
# Can we see the statistics table of the whole data ?
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000
# Is there any missing value at all columns ?
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print("How many customerID are there in the table ?")
print(len(data["customerID"].unique()))
print("\n")
print("How we can get only the rows from index 10 to 15 ?")
display(data.loc[10:15, :])
print("\n")
print("How we can reset index of the above results in a new table ? ")
df = data.loc[10:15, :]
df = df.reset_index(drop = True)
display(df)
print("\n")
print("How we can get the rows from index 10 to 15 of columns customerID, Partner, Dependents and Churn ?")
display(data.loc[10:15, ["customerID", "Partner", "Dependents", "Churn"]])
print("\n")
print("How we can get only the rows from index 10 of columns customerID, Partner, Dependents and Churn ?")
display(data.loc[10, ["customerID", "Partner", "Dependents", "Churn"]])
# Out:
# How many customerID are there in the table ?
# 7043
#
#
# How we can get only the rows from index 10 to 15 ?
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# 11  7469-LKBCI    Male              0      No         No      16          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 10            No             DSL                  Yes                   No
# 11            No              No  No internet service  No internet service
# 12           Yes     Fiber optic                   No                   No
# 13           Yes     Fiber optic                   No                  Yes
# 14            No     Fiber optic                  Yes                   No
# 15           Yes     Fiber optic                  Yes                  Yes
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 10                   No                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                  Yes                   No                  Yes
# 13                  Yes                   No                  Yes
# 14                  Yes                  Yes                  Yes
# 15                  Yes                  Yes                  Yes
#
#         StreamingMovies        Contract PaperlessBilling  \
# 10                   No  Month-to-month              Yes
# 11  No internet service        Two year               No
# 12                  Yes        One year               No
# 13                  Yes  Month-to-month              Yes
# 14                  Yes  Month-to-month              Yes
# 15                  Yes        Two year               No
#
#                 PaymentMethod  MonthlyCharges TotalCharges Churn
# 10               Mailed check           49.95       587.45    No
# 11    Credit card (automatic)           18.95        326.8    No
# 12    Credit card (automatic)          100.35       5681.1    No
# 13  Bank transfer (automatic)          103.70       5036.3   Yes
# 14           Electronic check          105.50      2686.05    No
# 15    Credit card (automatic)          113.25      7895.15    No
# How we can reset index of the above results in a new table ?
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# 1  7469-LKBCI    Male              0      No         No      16          Yes
# 2  8091-TTVAX    Male              0     Yes         No      58          Yes
# 3  0280-XJGEX    Male              0      No         No      49          Yes
# 4  5129-JLPIS    Male              0      No         No      25          Yes
# 5  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0            No             DSL                  Yes                   No
# 1            No              No  No internet service  No internet service
# 2           Yes     Fiber optic                   No                   No
# 3           Yes     Fiber optic                   No                  Yes
# 4            No     Fiber optic                  Yes                   No
# 5           Yes     Fiber optic                  Yes                  Yes
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No                   No                   No
# 1  No internet service  No internet service  No internet service
# 2                  Yes                   No                  Yes
# 3                  Yes                   No                  Yes
# 4                  Yes                  Yes                  Yes
# 5                  Yes                  Yes                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                   No  Month-to-month              Yes
# 1  No internet service        Two year               No
# 2                  Yes        One year               No
# 3                  Yes  Month-to-month              Yes
# 4                  Yes  Month-to-month              Yes
# 5                  Yes        Two year               No
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0               Mailed check           49.95       587.45    No
# 1    Credit card (automatic)           18.95        326.8    No
# 2    Credit card (automatic)          100.35       5681.1    No
# 3  Bank transfer (automatic)          103.70       5036.3   Yes
# 4           Electronic check          105.50      2686.05    No
# 5    Credit card (automatic)          113.25      7895.15    No
# How we can get the rows from index 10 to 15 of columns customerID, Partner, Dependents and Churn ?
#     customerID Partner Dependents Churn
# 10  9763-GRSKD     Yes        Yes    No
# 11  7469-LKBCI      No         No    No
# 12  8091-TTVAX     Yes         No    No
# 13  0280-XJGEX      No         No   Yes
# 14  5129-JLPIS      No         No    No
# 15  3655-SNQYZ     Yes        Yes    No
# How we can get only the rows from index 10 of columns customerID, Partner, Dependents and Churn ?
# customerID    9763-GRSKD
# Partner              Yes
# Dependents           Yes
# Churn                 No
# Name: 10, dtype: object

# %%
data = pd.read_csv('Telco Customer Churn.csv')

print("How we can change SeniorCitizen from int64 to object")
print("Original Type of SeniorCitizen :", data["SeniorCitizen"].dtypes)
data["SeniorCitizen"] = data["SeniorCitizen"].astype(str)
print("New Type of SeniorCitizen :", data["SeniorCitizen"].dtypes)
print("\n")

print("How we can extract the categorical and numeric columns ?")
CatFeatures = [col for col in data.columns if data[col].dtypes in ["object", "bool"]]
NumFeatures = [col for col in data.columns if data[col].dtypes in ["int64", "float64"]]
print("Categorical Features :", CatFeatures)
print("Numeric Features :", NumFeatures)
print("\n")

print("How we can show the all statistics of Numeric Features ?")
display(data.describe())
print("\n")

print("How we can show the all statistics of Categorical Features ?")
display(data[CatFeatures].describe(include='all'))
print("\n")

print("How we can get data from describe table ?")
NumStats = data[NumFeatures].describe(include='all')
CatStats = data[CatFeatures].describe(include='all')
MonthlyCharges_50 = NumStats.loc["50%", "MonthlyCharges"]
Churn_top_freq = CatStats.loc[["top", "freq"], "Churn"]
print("Total day minutes at 50 %(median) : \n", MonthlyCharges_50)
print("Top and Frequency of Top in Churn : \n", Churn_top_freq)
# Out:
# How we can change SeniorCitizen from int64 to object
# Original Type of SeniorCitizen : int64
# New Type of SeniorCitizen : object
#
#
# How we can extract the categorical and numeric columns ?
# Categorical Features : ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']
# Numeric Features : ['tenure', 'MonthlyCharges']
#
#
# How we can show the all statistics of Numeric Features ?
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000
# How we can show the all statistics of Categorical Features ?
#         customerID gender SeniorCitizen Partner Dependents PhoneService  \
# count         7043   7043          7043    7043       7043         7043
# unique        7043      2             2       2          2            2
# top     6736-DHUQI   Male             0      No         No          Yes
# freq             1   3555          5901    3641       4933         6361
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# count           7043            7043           7043         7043
# unique             3               3              3            3
# top               No     Fiber optic             No           No
# freq            3390            3096           3498         3088
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              7043        7043        7043            7043
# unique                3           3           3               3
# top                  No          No          No              No
# freq               3095        3473        2810            2785
#
#               Contract PaperlessBilling     PaymentMethod TotalCharges Churn
# count             7043             7043              7043         7043  7043
# unique               3                2                 4         6531     2
# top     Month-to-month              Yes  Electronic check                 No
# freq              3875             4171              2365           11  5174
# How we can get data from describe table ?
# Total day minutes at 50 %(median) :
#  70.35
# Top and Frequency of Top in Churn :
#  top       No
# freq    5174
# Name: Churn, dtype: object

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data = pd.read_csv('Telco Customer Churn.csv')

print("How we can draw chart for a numeric features ?")
feature = "tenure"
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
f.set_figheight(3)
f.set_figwidth(15)
sns.boxplot(data[feature], ax=ax_box)
sns.histplot(data=data, x=feature, ax=ax_hist)
plt.grid()
plt.show()

print("How we can map True/False to Yes/No in Churn feature  ?")
MapDict = {"Female" : 1, "Male": 0 }
data["gender"] = data["gender"].map(MapDict)
display(data.head())

print("How we can draw chart for a numeric feature according to a categorical feature ?")
feature = "tenure"
plt.figure(figsize = (15,3))
sns.boxplot(y ='Churn', x = feature, data = data)
plt.title(feature)
plt.grid()
plt.show()

print("How we can draw chart for two numeric features according to a categorical feature ?")
plt.figure(figsize=(15,5))
feature_x = "tenure"
feature_y = "MonthlyCharges"
feature_hue = "Churn"
sns.scatterplot(x = feature_x, y = feature_y, hue=feature_hue, data = data, legend='full')
plt.grid()
plt.show()
# Out:
# How we can draw chart for a numeric features ?
# How we can map True/False to Yes/No in Churn feature  ?
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG       1              0     Yes         No       1           No
# 1  5575-GNVDE       0              0      No         No      34          Yes
# 2  3668-QPYBK       0              0      No         No       2          Yes
# 3  7795-CFOCW       0              0      No         No      45           No
# 4  9237-HQITU       1              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes
# How we can draw chart for a numeric feature according to a categorical feature ?
# How we can draw chart for two numeric features according to a categorical feature ?

# %%
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can draw chart for a categorical feature ?")
feature = "Churn"
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
data[feature].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data[feature])
plt.show()

print("How we can draw chart for a categorical feature according to another categorical feature ?")
plt.figure(figsize=(15,5))
feature_x = "PhoneService"
feature_y = "tenure"
sns.stripplot(data[feature_x],data[feature_y])
plt.show()
# Out:
# How we can draw chart for a categorical feature ?
# How we can draw chart for a categorical feature according to another categorical feature ?

# %%
print("How we can split data into many data ? ")
feature_1 = ['customerID', 'MultipleLines']
data_1 = data[feature_1].copy()
display(data_1.head())

feature_2 = ['tenure', 'InternetService', 'Contract']
data_2 = data[feature_2].copy()
display(data_2.head())

feature = list(set(data.columns) - set(feature_1) - set(feature_2)) + ["Churn"]
data_Trans = data[feature].copy()
display(data_Trans.head())

print("How we can merge two data into one by cols ? ")
data_merge = pd.concat([data_1, data_2], axis = 1)
display(data_merge.head())
# Out:
# How we can split data into many data ?
#    customerID     MultipleLines
# 0  7590-VHVEG  No phone service
# 1  5575-GNVDE                No
# 2  3668-QPYBK                No
# 3  7795-CFOCW  No phone service
# 4  9237-HQITU                No
#    tenure InternetService        Contract
# 0       1             DSL  Month-to-month
# 1      34             DSL        One year
# 2       2             DSL  Month-to-month
# 3      45             DSL        One year
# 4       2     Fiber optic  Month-to-month
#   Dependents  gender              PaymentMethod TechSupport  SeniorCitizen  \
# 0         No  Female           Electronic check          No              0
# 1         No    Male               Mailed check          No              0
# 2         No    Male               Mailed check          No              0
# 3         No    Male  Bank transfer (automatic)         Yes              0
# 4         No  Female           Electronic check          No              0
#
#   TotalCharges PaperlessBilling StreamingMovies PhoneService OnlineSecurity  \
# 0        29.85              Yes              No           No             No
# 1       1889.5               No              No          Yes            Yes
# 2       108.15              Yes              No          Yes            Yes
# 3      1840.75               No              No           No            Yes
# 4       151.65              Yes              No          Yes             No
#
#   DeviceProtection StreamingTV Partner OnlineBackup Churn  MonthlyCharges  \
# 0               No          No     Yes          Yes    No           29.85
# 1              Yes          No      No           No    No           56.95
# 2               No          No      No          Yes   Yes           53.85
# 3              Yes          No      No           No    No           42.30
# 4               No          No      No           No   Yes           70.70
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes
# How we can merge two data into one by cols ?
#    customerID     MultipleLines  tenure InternetService        Contract
# 0  7590-VHVEG  No phone service       1             DSL  Month-to-month
# 1  5575-GNVDE                No      34             DSL        One year
# 2  3668-QPYBK                No       2             DSL  Month-to-month
# 3  7795-CFOCW  No phone service      45             DSL        One year
# 4  9237-HQITU                No       2     Fiber optic  Month-to-month

# %%
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can filter data by condition ?")
Condition1 = data["MonthlyCharges"] > 50
Condition2 = data["PhoneService"] == "Yes"
data_over100_IntlPlan1 = data[Condition1 & Condition2].copy()
display(data_over100_IntlPlan1.head())
print(data_over100_IntlPlan1.shape)

value1, value2 = 120 , "Yes"
data_less120_IntlPlan2 = data.query("`MonthlyCharges` < @value1 and `PhoneService` == @value2")
display(data_less120_IntlPlan2.head())
print(data_less120_IntlPlan2.shape)

print("How we can merge two data into one by rows ?")
data_merge = pd.concat([data_over100_IntlPlan1, data_less120_IntlPlan2])
display(data_merge.head())
print(data_merge.shape)
# Out:
# How we can filter data by condition ?
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 4            No     Fiber optic             No           No               No
# 5           Yes     Fiber optic             No           No              Yes
# 6           Yes     Fiber optic             No          Yes               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
# 5          No         Yes             Yes  Month-to-month              Yes
# 6          No         Yes              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges TotalCharges Churn
# 1             Mailed check           56.95       1889.5    No
# 2             Mailed check           53.85       108.15   Yes
# 4         Electronic check           70.70       151.65   Yes
# 5         Electronic check           99.65        820.5   Yes
# 6  Credit card (automatic)           89.10       1949.4    No
# (4555, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 4            No     Fiber optic             No           No               No
# 5           Yes     Fiber optic             No           No              Yes
# 6           Yes     Fiber optic             No          Yes               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
# 5          No         Yes             Yes  Month-to-month              Yes
# 6          No         Yes              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges TotalCharges Churn
# 1             Mailed check           56.95       1889.5    No
# 2             Mailed check           53.85       108.15   Yes
# 4         Electronic check           70.70       151.65   Yes
# 5         Electronic check           99.65        820.5   Yes
# 6  Credit card (automatic)           89.10       1949.4    No
# (6361, 21)
# How we can merge two data into one by rows ?
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 4            No     Fiber optic             No           No               No
# 5           Yes     Fiber optic             No           No              Yes
# 6           Yes     Fiber optic             No          Yes               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
# 5          No         Yes             Yes  Month-to-month              Yes
# 6          No         Yes              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges TotalCharges Churn
# 1             Mailed check           56.95       1889.5    No
# 2             Mailed check           53.85       108.15   Yes
# 4         Electronic check           70.70       151.65   Yes
# 5         Electronic check           99.65        820.5   Yes
# 6  Credit card (automatic)           89.10       1949.4    No
# (10916, 21)
